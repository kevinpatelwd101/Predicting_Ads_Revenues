# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression

# %%
training_data = pd.read_csv("file:///C:/Users/DELL/Downloads/Train_Data.csv")
testing_data = pd.read_csv("file:///C:/Users/DELL/Downloads/Test_Data.csv")

# %%
X = training_data.drop(["campaign","revenue","date","adgroup","ad","cost"],axis=1)
y = training_data["revenue"]
X
# Out:
#       impressions  clicks  conversions
# 0              24       6            0
# 1               1       0            0
# 2              13       4            0
# 3               5       4            0
# 4             247     126            4
# ...           ...     ...          ...
# 4566           19       6            0
# 4567            1       0            0
# 4568           16       8            1
# 4569           37      13            0
# 4570           19      10            0
#
# [4571 rows x 3 columns]

# %%
linreg = LinearRegression()
linreg.fit(X,y)
# Out:
# LinearRegression()

# %%
testing_data.drop(["campaign","date","adgroup","ad","cost"],axis=1,inplace=True)

# %%
arr = linreg.predict(testing_data)
print(arr)
for i in range(len(arr)):
    if arr[i]<0:
        arr[i]=0
# Out:
# [ 138.63117486  -20.03638781  -11.30556543   -9.98006162  -10.77036312
#   -11.03796427   54.81426811  -13.66396795  119.29632202  -11.05046625
#   468.92873319  -18.99098713  -17.11777903  348.9484379   -10.24766278
#   150.0380088   -22.4072923    98.99108033  -20.57159012  196.71580496
#   -12.08336495  -72.34631022  -10.24766278  487.56585807   -9.71246047
#   -11.03796427  689.60742949  104.44817896  -12.36346808  -10.50276196
#   628.6895954   -15.79227522 1223.14493428  365.1970966   196.21810857
#   -12.61856727  107.17419842  -26.61389896  -10.50276196  -10.26016475
#   -15.0144757   -34.79701705   -9.71246047  -33.50901916  -48.54975153
#    -9.18976013  -12.88616842  -10.24766278  -17.93308448  -21.59198685
#    -9.71246047  -13.42137074  -30.61541433  361.91087089   90.36027374
#   207.05223427   -9.18976013  -13.14126761  -10.77036312 1122.53910679
#   -10.77036312  349.06095566   -9.98006162  249.71812212  -12.09586693
# ...

# %%
res = pd.DataFrame(arr)
res.index = testing_data.index
res.columns = ["revenue"]
res.to_csv("first_sub.csv", index = False)
